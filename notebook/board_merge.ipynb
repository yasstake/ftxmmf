# %%
from exchange.board import *
from matplotlib import pyplot as plt

# %%
files = (
    'BB-2020-10-01T00-09-41.084127Z.log.gz',
    'BB-2020-10-01T01-00-58.670877Z.log.gz',
    'BB-2020-10-01T01-53-02.064144Z.log.gz',
    'BB-2020-10-01T02-44-49.406307Z.log.gz',
    'BB-2020-10-01T03-36-14.186767Z.log.gz',
    'BB-2020-10-01T04-27-59.817297Z.log.gz',
    'BB-2020-10-01T05-19-36.804052Z.log.gz',
    'BB-2020-10-01T06-11-06.849645Z.log.gz',
    'BB-2020-10-01T07-02-24.289180Z.log.gz',
    'BB-2020-10-01T07-54-13.840578Z.log.gz',
    'BB-2020-10-01T08-45-42.229831Z.log.gz',
    'BB-2020-10-01T09-37-01.732325Z.log.gz',
    'BB-2020-10-01T10-28-16.647548Z.log.gz')

root_path = '../DATA/BB/10/'

history = load_file(root_path + files[0])
history.setup_dollar_bar()

print(history.start_time)
print(history.end_time)
# Out:
# 2020-10-01 00:09:40.493802
# 2020-10-01 01:03:00.992505

# %%
plt.plot(history.dollar_bar['close'])
plt.show()

# %%
history.load(root_path + files[1])
history.load(root_path + files[2])
history.load(root_path + files[3])
history.load(root_path + files[4])
history.load(root_path + files[5])

print(history.start_time)
print(history.end_time)
# Out:
# 2020-10-01 00:09:40.493802
# 2020-10-01 05:21:05.792228

# %%
history.setup_dollar_bar()

plt.plot(history.dollar_bar['close'])
plt.show()

# %%
history.dollar_bar
# Out:
#                   time_stamp     open    close     high      low  sell_volume  \
# time
# 0    2020-10-01 00:13:03.634  10794.0  10792.0  10794.0  10792.0        3.368
# 1    2020-10-01 00:15:45.012  10792.0  10796.0  10796.0  10792.0        1.560
# 2    2020-10-01 00:17:46.406  10796.0  10791.5  10798.5  10791.5        3.308
# 3    2020-10-01 00:18:24.453  10791.5  10785.5  10791.5  10785.5        5.120
# 4    2020-10-01 00:22:37.969  10785.5  10789.5  10789.5  10785.5        2.980
# ...                      ...      ...      ...      ...      ...          ...
# 110  2020-10-01 04:54:44.921  10799.0  10799.0  10799.5  10799.0        5.764
# 111  2020-10-01 05:01:51.296  10799.0  10793.0  10799.0  10793.0        4.918
# 112  2020-10-01 05:07:09.574  10793.0  10792.0  10793.0  10792.0        3.879
# 113  2020-10-01 05:08:30.580  10792.0  10792.5  10792.5  10792.0        2.208
# 114  2020-10-01 05:18:01.463  10792.5  10797.0  10797.0  10792.0        0.773
#
#       buy_volume  bs_ratio
# time
# 0          1.300  0.385986
# 1          3.504  2.246154
# 2          1.527  0.461608
# 3          0.000  0.000000
# 4          1.855  0.622483
# ...          ...       ...
# 110        0.011  0.001908
# 111        0.051  0.010370
# 112        0.005  0.001289
# 113        3.837  1.737772
# 114        3.480  4.501940
#
# [115 rows x 8 columns]

# %%
history.update_price()
# Out:
# TOO SHORT DATA(partial record is not found)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-7aa50b9d44a5> in <module>
# ----> 1 history.update_price()
#       2
#
# ~/Projects/ftxmmf/exchange/board.py in update_price(self)
#     349     def update_price(self):
#     350         self.dollar_bar[['market_buy', 'market_sell', 'limit_buy', 'limit_sell']] = \
# --> 351             self.dollar_bar['time_stamp'].apply(self._calc_order_price)
#     352
#     353     def _calc_q_value(self, row):
#
# ~/.conda/envs/ftxmmf/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/Projects/ftxmmf/exchange/board.py in _calc_order_price(self, time)
#     343
#     344     def _calc_order_price(self, time):
# --> 345         market_prices = self.market_price(time)
#     346         limit_prices = self.limit_price(time)
#     347         return pd.Series([market_prices[0], market_prices[1], limit_prices[0], limit_prices[1]])
#
# ~/Projects/ftxmmf/exchange/board.py in market_price(self, time, volume)
#     272         :return: board price(ask_price, ask_size, bit_price, bit_size)
#     273         """
# --> 274         bit, ask = self.get_board(time)
#     275
#     276         bit_price = bit[0][0]
#
# ~/Projects/ftxmmf/exchange/board.py in get_board(self, time)
#     175
#     176     def get_board(self, time):
# --> 177         bit, ask = self._get_board_df(time)
#     178         bit_board = board_df_to_list(bit, False)
#     179         ask_board = board_df_to_list(ask, True)
#
# ~/Projects/ftxmmf/exchange/board.py in _get_board_df(self, time)
#     186         :return: asks, bits
#     187         """
# --> 188         df = self._select_board_df(time)
#     189         bit = df[df[ACTION] == Action.UPDATE_BIT]
#     190         bit = bit.drop_duplicates(subset=PRICE, keep='last')
#
# ~/Projects/ftxmmf/exchange/board.py in _select_board_df(self, time)
#     199         start_time = time - self.board_time_width
#     200         df = _chop_log_data(self.log_data, start=start_time, end=time)
# --> 201         partial_index = self._get_last_partial_index(df)
#     202         df = df.iloc[partial_index:]
#     203
#
# ~/Projects/ftxmmf/exchange/board.py in _get_last_partial_index(self, df)
#     215
#     216         partial = partial[-1:]
# --> 217         partial_index = partial.index[0]
#     218
#     219         '''
#
# ~/.conda/envs/ftxmmf/lib/python3.7/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    3927         if is_scalar(key):
#    3928             key = com.cast_scalar_indexer(key)
# -> 3929             return getitem(key)
#    3930
#    3931         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
history.update_q_value()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.conda/envs/ftxmmf/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4409             try:
# -> 4410                 return libindex.get_value_at(s, key)
#    4411             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-37e7629f367a> in <module>
# ----> 1 history.update_q_value()
#       2
#
# ~/Projects/ftxmmf/exchange/board.py in update_q_value(self)
#     399     def update_q_value(self):
#     400         self.dollar_bar[['q_market_buy', 'q_market_sell', 'q_limit_buy', 'q_limit_sell']] = \
# --> 401             self.dollar_bar.apply(self._calc_q_value, axis=1)
#     402
#     403     def ochlv(self):
#
# ~/.conda/envs/ftxmmf/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~/.conda/envs/ftxmmf/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~/.conda/envs/ftxmmf/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# --> 296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#     298             except ValueError as err:
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# ~/Projects/ftxmmf/exchange/board.py in _calc_q_value(self, row)
#     359         time_stamp = row['time_stamp']
#     360
# --> 361         market_buy = row['market_buy']
#     362         market_sell = row['market_sell']
#     363         limit_buy = row['limit_buy']
#
# ~/.conda/envs/ftxmmf/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/.conda/envs/ftxmmf/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4416                     raise InvalidIndexError(key)
#    4417                 else:
# -> 4418                     raise e1
#    4419             except Exception:
#    4420                 raise e1
#
# ~/.conda/envs/ftxmmf/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4402         k = self._convert_scalar_indexer(k, kind="getitem")
#    4403         try:
# -> 4404             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4405         except KeyError as e1:
#    4406             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'market_buy'

# %%
plt.plot(history.log_data[history.log_data['action']==3])
plt.show()

# %%
df = history.log_data.copy()
partial = df[df[ACTION] == Action.PARTIAL]

# %%
partial
# Out:
#         action                       time  sequence  price  volume  checksum
# 0            1 2020-10-01 00:09:40.493802         0    NaN     NaN       NaN
# 30079        1 2020-10-01 01:00:58.492630         0    NaN     NaN       NaN
# 51434        1 2020-10-01 01:53:02.492767         0    NaN     NaN       NaN
# 137792       1 2020-10-01 02:44:48.493907         0    NaN     NaN       NaN
# 240609       1 2020-10-01 03:36:14.493847         0    NaN     NaN       NaN
# 353995       1 2020-10-01 04:27:58.492621         0    NaN     NaN       NaN

# %%
partial[-2:-1]
# Out:
#         action                       time  sequence  price  volume  checksum
# 240609       1 2020-10-01 03:36:14.493847         0    NaN     NaN       NaN

# %%
p = partial[-2:-1]
p
# Out:
#         action                       time  sequence  price  volume  checksum
# 240609       1 2020-10-01 03:36:14.493847         0    NaN     NaN       NaN

# %%
p.index[0]
# Out:
# 240609

# %%
p.index.values[0]
# Out:
# 240609
